# %%
import cv2

# %%
img = cv2.imread('sellipi.webp')

# %%
img
# Out:
# array([[[ 49,  53,  60],
#         [ 54,  58,  67],
#         [ 64,  70,  80],
#         ...,
#         [146, 144, 144],
#         [149, 146, 147],
#         [152, 150, 150]],
#
#        [[ 48,  52,  58],
#         [ 44,  51,  59],
#         [ 60,  68,  78],
#         ...,
#         [132, 130, 130],
#         [134, 131, 132],
#         [134, 131, 132]],
#
#        [[ 47,  54,  60],
#         [ 39,  45,  53],
#         [ 48,  56,  66],
#         ...,
#         [146, 144, 144],
#         [138, 136, 136],
#         [137, 135, 135]],
#
#        ...,
#
#        [[ 43,  41,  39],
#         [ 37,  35,  33],
#         [ 43,  41,  39],
#         ...,
#         [ 42,  43,  40],
#         [ 31,  32,  30],
#         [ 38,  39,  37]],
#
#        [[ 30,  28,  26],
#         [ 32,  31,  29],
#         [ 30,  28,  26],
#         ...,
#         [ 61,  61,  59],
#         [ 52,  53,  51],
#         [ 47,  47,  45]],
#
#        [[ 37,  35,  33],
#         [ 37,  35,  33],
#         [ 52,  50,  48],
#         ...,
#         [ 35,  36,  33],
#         [ 41,  42,  39],
#         [ 55,  56,  53]]], dtype=uint8)

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(gray, (5,5),0)
canny = cv2.Canny(blur, threshold1=180, threshold2=200)

# %%
plt.imshow(canny)

# %%
cv2.imwrite('edges.jpg', canny)
