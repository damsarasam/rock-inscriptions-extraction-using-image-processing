# %%
import cv2

# %%
img = cv2.imread('IMG_5688.jpg')

# %%
img
# Out:
# array([[[  0,   4,   0],
#         [ 11,  19,  18],
#         [  0,   0,  10],
#         ...,
#         [143, 139, 138],
#         [139, 135, 134],
#         [140, 136, 135]],
#
#        [[  7,  15,   8],
#         [  0,   1,   0],
#         [  0,   3,  17],
#         ...,
#         [155, 151, 150],
#         [158, 154, 153],
#         [151, 147, 146]],
#
#        [[  0,   4,   0],
#         [  1,   6,   7],
#         [  0,   0,  12],
#         ...,
#         [138, 136, 135],
#         [130, 128, 127],
#         [127, 125, 124]],
#
#        ...,
#
#        [[ 99, 108, 111],
#         [137, 146, 149],
#         [114, 123, 126],
#         ...,
#         [  0,   0,   0],
#         [  6,   7,   5],
#         [  0,   1,   0]],
#
#        [[144, 153, 156],
#         [120, 129, 132],
#         [107, 116, 119],
#         ...,
#         [  1,   1,   1],
#         [  2,   3,   1],
#         [ 12,  13,  11]],
#
#        [[135, 144, 147],
#         [157, 166, 169],
#         [130, 139, 142],
#         ...,
#         [  2,   2,   2],
#         [ 12,  13,  11],
#         [  0,   1,   0]]], dtype=uint8)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x549>

# %%
from google.colab.patches import cv2_imshow
resized_img = cv2.resize(img, (int(img.shape[1]/2), int(img.shape[0]/2)))
cv2_imshow(resized_img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x274>

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
int(img.shape[1]/2)
# Out:
# 600

# %%
(int(img.shape[1]/2), int(img.shape[0]/2))
# Out:
# (600, 274)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(gray, (9,9),0)
canny = cv2.Canny(blur, threshold1=180, threshold2=210)

# %%
resized_img = cv2.resize(canny, (int(img.shape[1]/2), int(img.shape[0]/2)))
cv2_imshow(resized_img)
# Out:
# <PIL.Image.Image image mode=L size=600x274>

# %%
plt.imshow(canny)

# %%
cv2.imwrite('edges.jpg', canny)
